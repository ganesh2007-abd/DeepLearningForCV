# %%
import tensorflow as tf
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("train.csv",sep=",")
data.head()
# Out:
#    v.id  on road old  on road now  years      km  rating  condition  economy  \
# 0     1       535651       798186      3   78945       1          2       14
# 1     2       591911       861056      6  117220       5          9        9
# 2     3       686990       770762      2  132538       2          8       15
# 3     4       573999       722381      4  101065       4          3       11
# 4     5       691388       811335      6   61559       3          9       12
#
#    top speed  hp  torque  current price
# 0        177  73     123       351318.0
# 1        148  74      95       285001.5
# 2        181  53      97       215386.0
# 3        197  54     116       244295.5
# 4        160  53     105       531114.5

# %%
sns.pairplot(data,diag_kind='kde')

# %%
tensor_data = tf.constant(data)
tensor_data = tf.cast(tensor_data,tf.dtypes.float32)
tensor_data
# Out:
# <tf.Tensor: shape=(1000, 12), dtype=float32, numpy=
# array([[1.000000e+00, 5.356510e+05, 7.981860e+05, ..., 7.300000e+01,
#         1.230000e+02, 3.513180e+05],
#        [2.000000e+00, 5.919110e+05, 8.610560e+05, ..., 7.400000e+01,
#         9.500000e+01, 2.850015e+05],
#        [3.000000e+00, 6.869900e+05, 7.707620e+05, ..., 5.300000e+01,
#         9.700000e+01, 2.153860e+05],
#        ...,
#        [9.980000e+02, 6.463440e+05, 8.427330e+05, ..., 1.130000e+02,
#         8.900000e+01, 4.058710e+05],
#        [9.990000e+02, 5.355590e+05, 7.324390e+05, ..., 1.120000e+02,
#         1.280000e+02, 7.439800e+04],
#        [1.000000e+03, 5.901050e+05, 7.797430e+05, ..., 9.900000e+01,
#         9.600000e+01, 4.149385e+05]], dtype=float32)>

# %%
tensor_data = tf.random.shuffle(tensor_data)
tensor_data
# Out:
# <tf.Tensor: shape=(1000, 12), dtype=float32, numpy=
# array([[1.360000e+02, 6.257470e+05, 7.802630e+05, ..., 8.600000e+01,
#         1.230000e+02, 2.073525e+05],
#        [5.730000e+02, 6.712300e+05, 7.198020e+05, ..., 1.200000e+02,
#         1.140000e+02, 3.971830e+05],
#        [5.300000e+02, 6.322620e+05, 7.258390e+05, ..., 6.100000e+01,
#         1.150000e+02, 2.990195e+05],
#        ...,
#        [3.830000e+02, 5.871870e+05, 7.773970e+05, ..., 9.300000e+01,
#         1.010000e+02, 2.442290e+05],
#        [2.010000e+02, 6.624540e+05, 8.226250e+05, ..., 5.200000e+01,
#         1.200000e+02, 1.596145e+05],
#        [2.390000e+02, 6.520990e+05, 8.779980e+05, ..., 9.400000e+01,
#         9.900000e+01, 5.451710e+05]], dtype=float32)>

# %%
X = tensor_data[:,3:-1]
y = tensor_data[:,-1]
# X.shape
y = tf.expand_dims(y,axis=-1)
y.shape
# Out:
# TensorShape([1000, 1])
